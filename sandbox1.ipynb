# %%
import pandas as pd

df = pd.read_csv('data_productos/2022-02-BONAFONT-Productos.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15089 entries, 0 to 15088
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  15089 non-null  int64
#  1   Purchase Date       15089 non-null  object
#  2   Customer Name       15089 non-null  object
#  3   Payment Method      15089 non-null  object
#  4   Origen del Cliente  15089 non-null  object
#  5   Qty                 15089 non-null  float64
#  6   Total               15089 non-null  float64
#  7   Product Name        15089 non-null  object
#  8   Nombre Productos    15079 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.0+ MB

# %%
df.value_counts('Nombre Productos')
# Out:
# Nombre Productos
# Envase Más Agua Natural Bonafont 20L                              12753
# Agua Natural Bonafont 6x1L                                          793
# Agua Natural Bonafont 11L Sin Envase                                773
# Envase Más Agua Natural Bonafont 11L                                225
# Bomba de Agua Automática para Garrafón Bonafont                      97
# Termo Bonafont Amanecer diseño hojas Rosas 600ml                     79
# Termo Bonafont Amanecer con diseño Hojas Negro 600ml                 56
# Bomba para Garrafont Bonafont®                                       32
# Agua Fresca Juizzy Naranja 3L                                        30
# Termo Bonafont Traguito a Traguito Gotas 850 ml                      22
# Silk Alimento Líquido de Almendra Sin Azúcar 946mL                   21
# Termo Amanecer Bonafont Negro 600ml                                  21
# Termo Bonafont Traguito a Traguito Triángulos 850 ml                 16
# ...

# %%
# Mostrar las filas donde "Nombre Productos" está vacío
df[df['Nombre Productos'].isnull()]
# Out:
#                ID Purchase Date        Customer Name       Payment Method
# 4338   7000458827    2022-04-02     Anayeli Libreros  Pago Contra Entrega  \
# 9419   7000467416    2022-10-02          Cris Casleo  Pago Contra Entrega
# 9420   7000467416    2022-10-02          Cris Casleo  Pago Contra Entrega
# 10231  7000468847    2022-02-14      Maricarmen Daza  Pago Contra Entrega
# 12053  7000472138    2022-02-20      Maricarmen Daza  Pago Contra Entrega
# 12054  7000472138    2022-02-20      Maricarmen Daza  Pago Contra Entrega
# 12446  7000472939    2022-02-21     maria de de anda  Pago Contra Entrega
# 12447  7000472939    2022-02-21     maria de de anda  Pago Contra Entrega
# 12859  7000473704    2022-02-22  Alejandro Velázquez  Pago Contra Entrega
# 14898  7000477154    2022-02-28      Maricarmen Daza  Pago Contra Entrega
#
#       Origen del Cliente  Qty  Total
# 4338             Magento  1.0  157.0  \
# 9419              Google  1.0  252.0
# 9420              Google  1.0  252.0
# ...
